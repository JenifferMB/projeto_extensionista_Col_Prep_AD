# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
mesarios_pa_2024 = pd.read_csv('convocacao_mesarios_2024_PA.csv', encoding='latin1', delimiter=';')

# %%
mesarios_pa_2024
# Out:
#        DT_GERACAO HH_GERACAO  AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO  \
# 0      30/10/2024   04:23:04        2024         1    PA          5436
# 1      30/10/2024   04:23:04        2024         2    PA          4278
# 2      30/10/2024   04:23:04        2024         1    PA          4340
# 3      30/10/2024   04:23:04        2024         1    PA          4979
# 4      30/10/2024   04:23:04        2024         2    PA          4278
# ...           ...        ...         ...       ...   ...           ...
# 29141  30/10/2024   04:23:04        2024         1    PA          4154
# 29142  30/10/2024   04:23:04        2024         1    PA          4570
# 29143  30/10/2024   04:23:04        2024         1    PA          5975
# 29144  30/10/2024   04:23:04        2024         1    PA          4251
# 29145  30/10/2024   04:23:04        2024         1    PA          4642
#
#                 NM_MUNICIPIO  NR_ZONA  CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL  \
# ...

# %%
mesarios_pa_2024 = mesarios_pa_2024[mesarios_pa_2024["NM_MUNICIPIO"] == "BELÉM"]

# %%
infos_mesarios_pa_2024 = mesarios_pa_2024.describe(include='all')
nan_mesarios_pa_2024 = mesarios_pa_2024.isnull().sum()

# %%
infos_mesarios_pa_2024
# Out:
#         DT_GERACAO HH_GERACAO  AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO  \
# count         5683       5683      5683.0  5683.000000  5683        5683.0
# unique           1          1         NaN          NaN     1           NaN
# top     30/10/2024   04:23:04         NaN          NaN    PA           NaN
# freq          5683       5683         NaN          NaN  5683           NaN
# mean           NaN        NaN      2024.0     1.472110   NaN        4278.0
# std            NaN        NaN         0.0     0.499265   NaN           0.0
# min            NaN        NaN      2024.0     1.000000   NaN        4278.0
# 25%            NaN        NaN      2024.0     1.000000   NaN        4278.0
# 50%            NaN        NaN      2024.0     1.000000   NaN        4278.0
# 75%            NaN        NaN      2024.0     2.000000   NaN        4278.0
# max            NaN        NaN      2024.0     2.000000   NaN        4278.0
#
# ...

# %%
nan_mesarios_pa_2024
# Out:
# DT_GERACAO              0
# HH_GERACAO              0
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_pa_2024 = mesarios_pa_2024.drop(columns=["DT_GERACAO", "HH_GERACAO"])

# %%
infos_finais = mesarios_pa_2024.describe(include='all')
nan_finais = mesarios_pa_2024.isnull().sum()

# %%
infos_finais
# Out:
#         AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO NM_MUNICIPIO      NR_ZONA  \
# count       5683.0  5683.000000  5683        5683.0         5683  5683.000000
# unique         NaN          NaN     1           NaN            1          NaN
# top            NaN          NaN    PA           NaN        BELÉM          NaN
# freq           NaN          NaN  5683           NaN         5683          NaN
# mean        2024.0     1.472110   NaN        4278.0          NaN    61.396622
# std            0.0     0.499265   NaN           0.0          NaN    34.349816
# min         2024.0     1.000000   NaN        4278.0          NaN     1.000000
# 25%         2024.0     1.000000   NaN        4278.0          NaN    29.000000
# 50%         2024.0     1.000000   NaN        4278.0          NaN    73.000000
# 75%         2024.0     2.000000   NaN        4278.0          NaN    96.000000
# max         2024.0     2.000000   NaN        4278.0          NaN    98.000000
#
# ...

# %%
nan_finais
# Out:
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_pa_2024
# Out:
#        AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_ZONA  \
# 1            2024         2    PA          4278        BELÉM        1
# 4            2024         2    PA          4278        BELÉM        1
# 5            2024         1    PA          4278        BELÉM        1
# 7            2024         2    PA          4278        BELÉM       97
# 23           2024         2    PA          4278        BELÉM       73
# ...           ...       ...   ...           ...          ...      ...
# 29050        2024         1    PA          4278        BELÉM       30
# 29051        2024         2    PA          4278        BELÉM       30
# 29052        2024         1    PA          4278        BELÉM       30
# 29083        2024         2    PA          4278        BELÉM       76
# 29104        2024         1    PA          4278        BELÉM       76
#
#        CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# ...

# %%
mesarios_pa_2024.to_csv("mesarios_belem_2024.csv", index=False, encoding='latin1')

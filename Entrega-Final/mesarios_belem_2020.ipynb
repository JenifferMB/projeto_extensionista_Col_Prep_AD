# %%
import pandas as pd
import numpy as np

# %%
mesarios_pa_2020 = pd.read_csv('convocacao_mesarios_2020_PA.csv', encoding='latin1', delimiter=';')

# %%
mesarios_pa_2020
# Out:
#        DT_GERACAO HH_GERACAO  AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO  \
# 0      28/10/2024   03:49:41        2020         1    PA          4472
# 1      28/10/2024   03:49:41        2020         1    PA          4472
# 2      28/10/2024   03:49:41        2020         1    PA          4537
# 3      28/10/2024   03:49:41        2020         1    PA          4677
# 4      28/10/2024   03:49:41        2020         1    PA          4677
# ...           ...        ...         ...       ...   ...           ...
# 26365  28/10/2024   03:49:41        2020         1    PA          4235
# 26366  28/10/2024   03:49:41        2020         1    PA          4197
# 26367  28/10/2024   03:49:41        2020         1    PA          4286
# 26368  28/10/2024   03:49:41        2020         1    PA          5177
# 26369  28/10/2024   03:49:41        2020         1    PA          4235
#
#                 NM_MUNICIPIO  NR_ZONA  CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL  \
# ...

# %%
mesarios_pa_2020 = mesarios_pa_2020[mesarios_pa_2020["NM_MUNICIPIO"] == "BELÉM"]

# %%
infos_mesarios_pa_2020 = mesarios_pa_2020.describe(include="all")
nan_mesarios_pa_2020 = mesarios_pa_2020.isnull().sum()

# %%
infos_mesarios_pa_2020
# Out:
#         DT_GERACAO HH_GERACAO  AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO  \
# count         5680       5680      5680.0  5680.000000  5680        5680.0
# unique           1          1         NaN          NaN     1           NaN
# top     28/10/2024   03:49:41         NaN          NaN    PA           NaN
# freq          5680       5680         NaN          NaN  5680           NaN
# mean           NaN        NaN      2020.0     1.489437   NaN        4278.0
# std            NaN        NaN         0.0     0.499932   NaN           0.0
# min            NaN        NaN      2020.0     1.000000   NaN        4278.0
# 25%            NaN        NaN      2020.0     1.000000   NaN        4278.0
# 50%            NaN        NaN      2020.0     1.000000   NaN        4278.0
# 75%            NaN        NaN      2020.0     2.000000   NaN        4278.0
# max            NaN        NaN      2020.0     2.000000   NaN        4278.0
#
# ...

# %%
nan_mesarios_pa_2020
# Out:
# DT_GERACAO              0
# HH_GERACAO              0
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_pa_2020 = mesarios_pa_2020.drop(columns=["DT_GERACAO", "HH_GERACAO"])

# %%
infos_finais = mesarios_pa_2020.describe(include='all')
nan_finais = mesarios_pa_2020.isnull().sum()

# %%
infos_finais
# Out:
#         AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO NM_MUNICIPIO      NR_ZONA  \
# count       5680.0  5680.000000  5680        5680.0         5680  5680.000000
# unique         NaN          NaN     1           NaN            1          NaN
# top            NaN          NaN    PA           NaN        BELÉM          NaN
# freq           NaN          NaN  5680           NaN         5680          NaN
# mean        2020.0     1.489437   NaN        4278.0          NaN    64.241549
# std            0.0     0.499932   NaN           0.0          NaN    33.853253
# min         2020.0     1.000000   NaN        4278.0          NaN     1.000000
# 25%         2020.0     1.000000   NaN        4278.0          NaN    29.000000
# 50%         2020.0     1.000000   NaN        4278.0          NaN    76.000000
# 75%         2020.0     2.000000   NaN        4278.0          NaN    96.000000
# max         2020.0     2.000000   NaN        4278.0          NaN    98.000000
#
# ...

# %%
nan_finais
# Out:
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_pa_2020
# Out:
#        AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_ZONA  \
# 20           2020         1    PA          4278        BELÉM       97
# 21           2020         1    PA          4278        BELÉM       97
# 22           2020         1    PA          4278        BELÉM       97
# 23           2020         1    PA          4278        BELÉM       97
# 24           2020         1    PA          4278        BELÉM       97
# ...           ...       ...   ...           ...          ...      ...
# 26354        2020         1    PA          4278        BELÉM       98
# 26355        2020         1    PA          4278        BELÉM       95
# 26360        2020         2    PA          4278        BELÉM       95
# 26361        2020         2    PA          4278        BELÉM       95
# 26362        2020         2    PA          4278        BELÉM       95
#
#        CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL         DS_ESTADO_CIVIL  \
# ...

# %%
mesarios_pa_2020.to_csv("mesarios_belem_2020.csv", index=False, encoding='latin1')

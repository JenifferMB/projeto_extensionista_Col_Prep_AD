# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
mesarios_rs_2020 = pd.read_csv('convocacao_mesarios_2020_RS.csv', encoding='latin1', delimiter=';')

# %%
mesarios_rs_2020
# Out:
#        DT_GERACAO HH_GERACAO  AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO  \
# 0      28/10/2024   03:49:41        2020         2    RS         88013
# 1      28/10/2024   03:49:41        2020         2    RS         88013
# 2      28/10/2024   03:49:41        2020         1    RS         88013
# 3      28/10/2024   03:49:41        2020         1    RS         88013
# 4      28/10/2024   03:49:41        2020         1    RS         88013
# ...           ...        ...         ...       ...   ...           ...
# 47901  28/10/2024   03:49:41        2020         1    RS         89338
# 47902  28/10/2024   03:49:41        2020         1    RS         84972
# 47903  28/10/2024   03:49:41        2020         1    RS         88889
# 47904  28/10/2024   03:49:41        2020         1    RS         89338
# 47905  28/10/2024   03:49:41        2020         1    RS         89338
#
#        NM_MUNICIPIO  NR_ZONA  CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL  \
# ...

# %%
mesarios_rs_2020 = mesarios_rs_2020[mesarios_rs_2020["NM_MUNICIPIO"] == "PORTO ALEGRE"]

# %%
infos_mesarios_rs_2020 = mesarios_rs_2020.describe(include='all')
nan_mesarios_rs_2020 = mesarios_rs_2020.isnull().sum()

# %%
infos_mesarios_rs_2020
# Out:
#         DT_GERACAO HH_GERACAO  AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO  \
# count         5639       5639      5639.0  5639.000000  5639        5639.0
# unique           1          1         NaN          NaN     1           NaN
# top     28/10/2024   03:49:41         NaN          NaN    RS           NaN
# freq          5639       5639         NaN          NaN  5639           NaN
# mean           NaN        NaN      2020.0     1.480759   NaN       88013.0
# std            NaN        NaN         0.0     0.499674   NaN           0.0
# min            NaN        NaN      2020.0     1.000000   NaN       88013.0
# 25%            NaN        NaN      2020.0     1.000000   NaN       88013.0
# 50%            NaN        NaN      2020.0     1.000000   NaN       88013.0
# 75%            NaN        NaN      2020.0     2.000000   NaN       88013.0
# max            NaN        NaN      2020.0     2.000000   NaN       88013.0
#
# ...

# %%
nan_mesarios_rs_2020
# Out:
# DT_GERACAO              0
# HH_GERACAO              0
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_rs_2020 = mesarios_rs_2020.drop(columns=["DT_GERACAO", "HH_GERACAO"])

# %%
infos_finais = mesarios_rs_2020.describe(include='all')
nan_finais = mesarios_rs_2020.isnull().sum()

# %%
infos_finais
# Out:
#         AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO  NM_MUNICIPIO  \
# count       5639.0  5639.000000  5639        5639.0          5639
# unique         NaN          NaN     1           NaN             1
# top            NaN          NaN    RS           NaN  PORTO ALEGRE
# freq           NaN          NaN  5639           NaN          5639
# mean        2020.0     1.480759   NaN       88013.0           NaN
# std            0.0     0.499674   NaN           0.0           NaN
# min         2020.0     1.000000   NaN       88013.0           NaN
# 25%         2020.0     1.000000   NaN       88013.0           NaN
# 50%         2020.0     1.000000   NaN       88013.0           NaN
# 75%         2020.0     2.000000   NaN       88013.0           NaN
# max         2020.0     2.000000   NaN       88013.0           NaN
#
#             NR_ZONA    CD_GENERO DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  \
# count   5639.000000  5639.000000      5639      5639.000000            5639
# ...

# %%
nan_finais
# Out:
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_rs_2020
# Out:
#        AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO  NM_MUNICIPIO  NR_ZONA  \
# 0            2020         2    RS         88013  PORTO ALEGRE        2
# 1            2020         2    RS         88013  PORTO ALEGRE        2
# 2            2020         1    RS         88013  PORTO ALEGRE        2
# 3            2020         1    RS         88013  PORTO ALEGRE        2
# 4            2020         1    RS         88013  PORTO ALEGRE        2
# ...           ...       ...   ...           ...           ...      ...
# 47863        2020         1    RS         88013  PORTO ALEGRE      161
# 47868        2020         2    RS         88013  PORTO ALEGRE      161
# 47878        2020         2    RS         88013  PORTO ALEGRE      161
# 47879        2020         2    RS         88013  PORTO ALEGRE      161
# 47893        2020         2    RS         88013  PORTO ALEGRE      161
#
#        CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# ...

# %%
mesarios_rs_2020.to_csv("mesarios_poa_2020.csv", index=False, encoding='latin1')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
mesarios_rs_2024 = pd.read_csv('convocacao_mesarios_2024_RS.csv', encoding='latin1', delimiter=';')

# %%
mesarios_rs_2024
# Out:
#        DT_GERACAO HH_GERACAO  AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO  \
# 0      30/10/2024   04:23:04        2024         1    RS         88153
# 1      30/10/2024   04:23:04        2024         1    RS         86355
# 2      30/10/2024   04:23:04        2024         1    RS         89435
# 3      30/10/2024   04:23:04        2024         1    RS         85693
# 4      30/10/2024   04:23:04        2024         1    RS         85073
# ...           ...        ...         ...       ...   ...           ...
# 53435  30/10/2024   04:23:04        2024         1    RS         98256
# 53436  30/10/2024   04:23:04        2024         1    RS         87882
# 53437  30/10/2024   04:23:04        2024         2    RS         87912
# 53438  30/10/2024   04:23:04        2024         1    RS         86835
# 53439  30/10/2024   04:23:04        2024         2    RS         88013
#
#               NM_MUNICIPIO  NR_ZONA  CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL  \
# ...

# %%
mesarios_rs_2024 = mesarios_rs_2024[mesarios_rs_2024["NM_MUNICIPIO"] == "PORTO ALEGRE"]

# %%
infos_mesarios_rs_2024 = mesarios_rs_2024.describe(include='all')
nan_mesarios_rs_2024 = mesarios_rs_2024.isnull().sum()

# %%
infos_mesarios_rs_2024
# Out:
#         DT_GERACAO HH_GERACAO  AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO  \
# count         6169       6169      6169.0  6169.000000  6169        6169.0
# unique           1          1         NaN          NaN     1           NaN
# top     30/10/2024   04:23:04         NaN          NaN    RS           NaN
# freq          6169       6169         NaN          NaN  6169           NaN
# mean           NaN        NaN      2024.0     1.493759   NaN       88013.0
# std            NaN        NaN         0.0     0.500002   NaN           0.0
# min            NaN        NaN      2024.0     1.000000   NaN       88013.0
# 25%            NaN        NaN      2024.0     1.000000   NaN       88013.0
# 50%            NaN        NaN      2024.0     1.000000   NaN       88013.0
# 75%            NaN        NaN      2024.0     2.000000   NaN       88013.0
# max            NaN        NaN      2024.0     2.000000   NaN       88013.0
#
# ...

# %%
nan_mesarios_rs_2024
# Out:
# DT_GERACAO              0
# HH_GERACAO              0
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_rs_2024 = mesarios_rs_2024.drop(columns=["DT_GERACAO", "HH_GERACAO"])

# %%
infos_finais = mesarios_rs_2024.describe(include='all')
nan_finais = mesarios_rs_2024.isnull().sum()

# %%
infos_finais
# Out:
#         AA_ELEICAO     NR_TURNO SG_UF  CD_MUNICIPIO  NM_MUNICIPIO  \
# count       6169.0  6169.000000  6169        6169.0          6169
# unique         NaN          NaN     1           NaN             1
# top            NaN          NaN    RS           NaN  PORTO ALEGRE
# freq           NaN          NaN  6169           NaN          6169
# mean        2024.0     1.493759   NaN       88013.0           NaN
# std            0.0     0.500002   NaN           0.0           NaN
# min         2024.0     1.000000   NaN       88013.0           NaN
# 25%         2024.0     1.000000   NaN       88013.0           NaN
# 50%         2024.0     1.000000   NaN       88013.0           NaN
# 75%         2024.0     2.000000   NaN       88013.0           NaN
# max         2024.0     2.000000   NaN       88013.0           NaN
#
#             NR_ZONA    CD_GENERO DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  \
# count   6169.000000  6169.000000      6169      6169.000000            6169
# ...

# %%
nan_finais
# Out:
# AA_ELEICAO              0
# NR_TURNO                0
# SG_UF                   0
# CD_MUNICIPIO            0
# NM_MUNICIPIO            0
# NR_ZONA                 0
# CD_GENERO               0
# DS_GENERO               0
# CD_ESTADO_CIVIL         0
# DS_ESTADO_CIVIL         0
# CD_FAIXA_ETARIA         0
# DS_FAIXA_ETARIA         0
# CD_GRAU_ESCOLARIDADE    0
# DS_GRAU_ESCOLARIDADE    0
# TP_CONVOCACAO           0
# TP_COMPARECIMENTO       0
# QT_MESARIOS_PERFIL      0
# dtype: int64

# %%
mesarios_rs_2024
# Out:
#        AA_ELEICAO  NR_TURNO SG_UF  CD_MUNICIPIO  NM_MUNICIPIO  NR_ZONA  \
# 10           2024         1    RS         88013  PORTO ALEGRE      161
# 12           2024         1    RS         88013  PORTO ALEGRE      161
# 19           2024         2    RS         88013  PORTO ALEGRE        1
# 24           2024         2    RS         88013  PORTO ALEGRE      112
# 31           2024         2    RS         88013  PORTO ALEGRE      158
# ...           ...       ...   ...           ...           ...      ...
# 53394        2024         2    RS         88013  PORTO ALEGRE      114
# 53397        2024         1    RS         88013  PORTO ALEGRE      114
# 53427        2024         1    RS         88013  PORTO ALEGRE      160
# 53432        2024         1    RS         88013  PORTO ALEGRE      160
# 53439        2024         2    RS         88013  PORTO ALEGRE      111
#
#        CD_GENERO  DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# ...

# %%
mesarios_rs_2024.to_csv("mesarios_poa_2024.csv", index=False, encoding='latin1')
